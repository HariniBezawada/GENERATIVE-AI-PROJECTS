# %% [markdown]
# <a href="https://colab.research.google.com/github/HariniBezawada/GENERATIVE-AI-PROJECTS/blob/main/Text_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
notes_generator = pipeline('text-generation', model='gpt2')
chapter = input("Enter chapter name:")
prompt_notes=f"""
write detailed study notes for the chapter:
 {chapter}
 Include explanation,exmples and key points
"""
detailed_notes=notes_generator(prompt_notes,max_length=300,num_return_sequences=1)
print("\n DETAILER NOTES:\n")
print(detailed_notes[0]['generated_text'])
prompt_summary=f"""
Summarize the chapter {chapter} into one page
make it simple and exam-oriented.
"""
something = notes_generator(prompt_summary,max_length=200,num_return_sequences=1)
print("\n ONE_PAGE_SUMMARY:\n")
print(something[0]['generated_text'])
prompt_definitions = f"""
List important definitions and formulas from the chapter:
 {chapter}
      Use bullet points
      """
definitions = notes_generator(prompt_definitions, max_length=200, num_return_sequences=1)
print("\nDEFINITIONS:\n")
print(definitions[0]['generated_text'])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Enter chapter name:GEN AI
# Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=300) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  DETAILER NOTES:
#
#
# write detailed study notes for the chapter:
#  GEN AI
#  Include explanation,exmples and key points
#
# You can also put:
#
# a copy of the chapter in your paper
#
# a PDF of the chapter
#
# the chapter in your paper Acknowledgements
#
# The authors thank the following people for their help in this project:
#
# Dr. James B. Hickey
#
# Professor of Neurobiology, University of Chicago
#
# Dr. John H. Vee
#
# Professor of Psychology, University of Toronto
#
# Dr. Paul Lee
#
# Professor of Psychology, University of Toronto
#
# Dr. Gary M. Wintrich
#
# Professor of Psychiatry, University of Toronto
#
# Dr. Mark W.
#
# Professor of Neurology, University of Toronto
#
# Dr. Joseph W.
#
# Professor of Psychology, University of Toronto
#
# Dr. Mark W.
#
# Professor of Neuroscience, University of Toronto
#
# Gerald W.
#
# Professor of Psychology, University of Toronto
#
# Dr. Daniel W.
#
# Professor of Neuroscience, University of Toronto
#
# Dr. Andrew Williams
#
# Professor of Political Science, University of Toronto
#
# Dr. Michael Williams
#
# Professor of Psychology, University of Toronto
#
# Dr. Eric Williams
#
# Professor of Medicine, University of Toronto
#
# Dr. Eric Williams
#
# Professor of
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  ONE_PAGE_SUMMARY:
#
#
# Summarize the chapter GEN AI into one page
# make it simple and exam-oriented.
#
# It's a simple text-based book with a lot of simple-to-use syntax.
#
# It's not a hard book to read.
#
# It's a great introduction to the basics of Gen AI.
#
# It makes learning Gen AI easier than ever.
#
# This book introduces to the reader the basics of Gen AI.
#
# The book is easy to understand, but also very easy to understand and to use.
#
# Gen AI is a really basic text book.
#
# Because it contains only a few lines of text, it's not as hard as you might think.
#
# This is the book for everyone.
#
# It's a great introduction to Gen AI and you should never forget it.
#
# It's a good introduction to Gen AI, but it's not for everyone.
#
# You don't need to know Gen AI or Gen AI is just for geniuses, it's for the future.
#
# It's a good introduction to Gen AI and you should never forget it.
#
# This is a great book for the future.
#
# This is a clear and easy introduction to Gen AI.
#
# Gen AI is a clear and easy introduction to Gen AI.
#
# It's a good introduction to Gen AI
#
# DEFINITIONS:
#
#
# List important definitions and formulas from the chapter:
#  GEN AI
#       Use bullet points
#
#
# The first two sections of the chapter are:
#
# GEN AI, the type of AI (a "class") that can be applied to every class. The first two sections are: GEN AI, one of the main types of AI (in the "class") that can be applied to every class.
#
# The first two sections of the chapter are: GEN AI, the type of AI (a "class") that can be applied to every class. GEN AI, the first type of AI that can be applied to every class.
#
# The following sections are also important for AI:
#
# GEN AI, the type of AI (in the "class") that can be applied to every class.
#
# The following sections are also important for AI: GEN AI, the type of AI (in the "class") that can be applied to every class. GEN AI, the first type of AI that can be applied to every class.
#
# The following sections are also important for AI: GEN AI, the type of AI (in the "class") that can be applied to every class. GEN AI, the
